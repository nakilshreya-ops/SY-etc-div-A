# %%
a=10
b=10
if a==b:
  print("a and b are equal")
else:
  print("a and b are not equal")
# Out:
# a and b are equal

# %%
age=int(input("enter the age of citizen:"))
citizen=input("enter the citizen:")
if age>=18:
  if citizen=="indian":
   print("it is eligible to vote")
  else:
    print("it is not eligible to vote")

else:
  print("it is not eligible to vote")
# Out:
# enter the age of citizen:17
# enter the citizen:indian
# it is not eligible to vote

# %%
gender=input("enter the gender:")
state=input("enter the state:")
if gender=="female":
 if state=="maharashtra":
  print("half ticket for bus pass")
 else :
   print("full ticket for bus pass")

else:
  print("full ticket for bus")
# Out:
# enter the gender:female
# enter the state:maharashtra
# half ticket for bus pass

# %%
mark=int(input("enter the mark of student:"))
if mark>=90:
  print("grade A")
elif mark>=80 and mark<=90:
  printf("grade B")
elif mark>=70 and mark<=80:
  printf("grade c")

else:
  print("fail")
# Out:
# enter the mark of student:94
# grade A

# %%
num=int (input("enter the number:"))
if num%2==0:
  print("even")

else:
  print("odd")
# Out:
# enter the number:4
# even

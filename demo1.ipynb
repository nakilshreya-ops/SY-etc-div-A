# %%
a=10
b=20
print("sum:",a+b)
# Out:
# sum: 30

# %%
name="shreya"
age=19
print("my name is:",name)
print("my age is:",age)
# Out:
# my name is: shreya
# my age is: 19

# %%
print("hello shreya",)
# Out:
# hello shreya

# %%
print("hello",end=" ")
print("shreya")
# Out:
# hello shreya

# %%
a=int(input("enter the first number:") )
b=int(input("enter the second number:"))
print("sum",a+b)
print(type(a))
# Out:
# enter the first number:10
# enter the second number:20
# sum 30
# <class 'int'>

# %%
name="shreya"
age=19
college="DKTE"
print(f"my name is {name} and my age is {age} studying in {college}")
# Out:
# my name is shreya. and my age is 19 studying in DKTE

# %%
print("shreya","nakil",sep="-")
# Out:
# shreya-nakil

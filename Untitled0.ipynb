# %%
list1=['samruddhi','shreya']
print(list1)
# Out:
# ['samruddhi', 'shreya']

# %%
list1=["shreya","nakil"]
list2=['samruddhi','patil']
print(list1+list2)
# Out:
# ['shreya', 'nakil', 'samruddhi', 'patil']

# %%
list1=['samruddhi','shreya']
print(list1*3)
# Out:
# ['samruddhi', 'shreya', 'samruddhi', 'shreya', 'samruddhi', 'shreya']

# %%
list1=[40,50,60,70,80]

print(list1[1:4])
# Out:
# [50, 60, 70]

# %%
list1=[40,50,60,70,80]
list1.append(90)
print(list1)
# Out:
# [40, 50, 60, 70, 80, 90]

# %%
list1=[40,50,60,70,80]
list2=[10,20,30]
list1.extend(list2)
print(list1)
# Out:
# [40, 50, 60, 70, 80, 10, 20, 30]

# %%
list1.pop()
print(list1)
# Out:
# [40, 50, 60, 70, 80, 10, 20]

# %%
list1=[40,50,60,70,80,80,80]
print(list1.count(80))
# Out:
# 3

# %%
print(sum(list1))
# Out:
# 460

# %%
print(max(list1))
# Out:
# 80

# %%
print(min(list1))
# Out:
# 40

# %%
list1.remove(70)
print(list1)
# Out:
# [40, 50, 60]

# %%
list1=[50,40,10,20,70]
list1.sort()
print(list1)
list1.sort(reverse=True)
print(list1)
# Out:
# [10, 20, 40, 50, 70]
# [70, 50, 40, 20, 10]

# %%
 list1=[10,20,30]
 list2=[40,50,60]
 list3=[70,80,90]
 print(list(zip(list1,list2,list3)))
# Out:
# [(10, 40, 70), (20, 50, 80), (30, 60, 90)]

# %%
list=[
    [1,2,3],
    [3,4,5],
    [6,7,8]
]
print(list)
# Out:
# [[1, 2, 3], [3, 4, 5], [6, 7, 8]]
